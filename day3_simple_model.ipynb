# %%
# !pip install --upgrade tables
# !pip install eli5
# Out:
# Requirement already up-to-date: tables in /usr/local/lib/python3.6/dist-packages (3.6.1)
# ...

# %%
import pandas as pd
import numpy as np

from sklearn.dummy import DummyRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_absolute_error as mae
from sklearn.model_selection import cross_val_score

import eli5
from eli5.sklearn import PermutationImportance

# %%
cd "/content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_two/dw_matrix_cargb-"
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_two/dw_matrix_cargb-

# %% [markdown]
# Wczytywanie danych i sprawdzenie ilosci wierszy i kolumn

# %%
df = pd.read_hdf('data/car.h5')
df.shape
# Out:
# (106494, 155)

# %% [markdown]
# Patrzymy jakie mamy kolumny

# %%
df.columns
# Out:
# Index(['breadcrumb', 'created_at', 'price_currency', 'price_details',
#        'price_value', 'seller_address', 'seller_name', 'seller_type',
#        'feature_czujniki-parkowania-przednie',
#        'feature_poduszka-powietrzna-chroniąca-kolana',
#        ...
#        'param_pearl', 'param_stan', 'param_wersja', 'param_emisja-co2',
#        'param_body-type', 'param_matowy', 'param_bezwypadkowy',
#        'param_akryl-(niemetalizowany)', 'param_monthly-payment-value',
#        'car_id'],
#       dtype='object', length=155)

# %% [markdown]
# Dummy Model
# Sprawdzamy jakie mamy kolumny typu number

# %%
df.select_dtypes(np.number).columns
# Out:
# Index(['price_value', 'car_id'], dtype='object')

# %%
feats = ['car_id']
X = df[feats].values
y = df['price_value'].values

model = DummyRegressor()
model.fit(X, y)
y_pred = model.predict(X)

mae(y, y_pred)
# Out:
# 39465.934630440985

# %% [markdown]
# Patrzymy które kolumny zawieraja słowo 'price'

# %%
[x for x in df.columns if 'price' in x]
# Out:
# ['price_currency', 'price_details', 'price_value']

# %% [markdown]
# Cena jest 106290 w złotych i 204 w euro

# %%
df['price_currency'].value_counts()
# Out:
# PLN    106290
# EUR       204
# Name: price_currency, dtype: int64

# %% [markdown]
# Patrzymy jaki % samochodów - ich cene mamy w EURO  99,8% samochodów jest a złotówkach

# %%
df['price_currency'].value_counts(normalize=True) * 100
# Out:
# PLN    99.80844
# EUR     0.19156
# Name: price_currency, dtype: float64

# %% [markdown]
# Usuwamy wszystkie ogłoszenia z ceną w EURO i sprawdzamy czy zgadza się ich ilość

# %%
df = df[ df['price_currency'] !='EUR']
df.shape
# Out:
# (106290, 155)

# %% [markdown]
# Przygotowanie Cech

# %%
df.head()
# Out:
#                                           breadcrumb  ... car_id
# 0    [Osobowe, Dacia, Logan, Dacia Logan II (2012-)]  ...      0
# 2  [Osobowe, Peugeot, 3008, Peugeot 3008 I (2009-...  ...      2
# 3  [Osobowe, Porsche, Cayenne, Porsche Cayenne II...  ...      3
# 4  [Osobowe, Peugeot, 308, Peugeot 308 T7 (2008-2...  ...      4
# 5  [Osobowe, Volkswagen, Golf, Volkswagen Golf VI...  ...      5
#
# [5 rows x 155 columns]

# %% [markdown]
# Przegladamy wszystkie kolumny przy pomocy pętli FOR

# %%
for feat in df.columns:
  print(feat)
# Out:
# breadcrumb
# created_at
# price_currency
# price_details
# price_value
# seller_address
# seller_name
# seller_type
# feature_czujniki-parkowania-przednie
# feature_poduszka-powietrzna-chroniąca-kolana
# feature_kurtyny-powietrzne
# feature_klimatyzacja-dwustrefowa
# feature_światła-led
# feature_czujnik-zmierzchu
# feature_elektrycznie-ustawiane-lusterka
# feature_asr-(kontrola-trakcji)
# feature_poduszka-powietrzna-kierowcy
# feature_cd
# feature_elektryczne-szyby-przednie
# feature_poduszka-powietrzna-pasażera
# feature_system-start-stop
# feature_światła-do-jazdy-dziennej
# feature_komputer-pokładowy
# feature_elektryczne-szyby-tylne
# feature_klimatyzacja-manualna
# feature_tapicerka-welurowa
# feature_czujnik-deszczu
# feature_światła-przeciwmgielne
# feature_ogrzewanie-postojowe
# feature_radio-niefabryczne
# feature_regulowane-zawieszenie
# feature_ogranicznik-prędkości
# feature_zmieniarka-cd
# feature_szyberdach
# feature_isofix
# feature_asystent-pasa-ruchu
# ...

# %% [markdown]
# Chcemy przypisac w sposób indywidualny ID dla każdego koloru kończymy [0] i otrzymujemy same ID kolorów

# %%
df['param_color'].factorize()[0]
# Out:
# array([-1, -1, -1, ..., -1, -1, -1])

# %%
SUFFIX_CAT = '__cat'
for feat in df.columns:
  if isinstance(df[feat][0], list): continue

  factorized_values = df[feat].factorize()[0]
  if SUFFIX_CAT in feat:
    df[feat] = factorized_values
  else:
    df[feat + SUFFIX_CAT] = factorized_values

# %% [markdown]
# Usuwamy z cech cenę gdyz jest to zmienna docelowa

# %%
cat_feats = [x for x in df.columns if SUFFIX_CAT in x]
cat_feats = [x for x in cat_feats if 'price' not in x]
len(cat_feats)
# Out:
# 151

# %% [markdown]
# Odpalamy Model

# %%
X = df[cat_feats].values
y = df['price_value'].values

model = DecisionTreeRegressor(max_depth=5)
scores = cross_val_score(model, X, y, cv=3, scoring='neg_mean_absolute_error')
np.mean(scores)
# Out:
# -19566.588937368328

# %% [markdown]
# Sprawdzamy które cechy wyglądają na ciekawsze
# Tworzymy jeszcze raz model

# %%
m = DecisionTreeRegressor(max_depth=5)
m.fit(X, y)

imp = PermutationImportance(m, random_state=0).fit(X, y)
eli5.show_weights(imp, feature_names=cat_feats)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2533
#
#                     &plusmn; 0.0040
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 param_napęd__cat
#             </td>
# ...

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/matrix_two/dw_matrix_cargb-

# %%
# !git -e
